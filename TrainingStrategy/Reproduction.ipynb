# %%
run main_earlystop.py
# Out:
# -----Importing Dataset-----
# (145, 145, 200)
# The class numbers of the HSI data is: 16
# -----Importing Setting Parameters-----
# iter: 0
# Train size:  307
# Test size:  9942
# Validation size:  307
# -----Selecting Small Pieces from the Original Cube Data-----
# training on  cuda
# d:\ProgramData\Anaconda3\lib\site-packages\torch\optim\lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# epoch 1, train loss 1.986292, train acc 0.440, valida loss 2.209240, valida acc 0.521, time 2.1 sec
# ...

# %%
run main_proposed.py
# Out:
# -----Importing Dataset-----
# (145, 145, 200)
# The class numbers of the HSI data is: 16
# -----Importing Setting Parameters-----
# iter: 0
# Train size:  307
# Test size:  9942
# Validation size:  307
# -----Selecting Small Pieces from the Original Cube Data-----
# training on  cuda
# d:\ProgramData\Anaconda3\lib\site-packages\torch\optim\lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# epoch 1, train loss 1.927464, train acc 0.427, valida loss 2.289402, valida acc 0.541, time 0.4 sec
# ...
